# %% [markdown]
# # Exploratory Data Analysis On World Health Organization Covid19 Report
#
# Globally, as of 8:38pm CEST, 4 May 2022, there have been 512,607,587 confirmed cases of COVID-19, including 6,243,038 deaths, reported to WHO. As of 2 May 2022, a total of 11,560,378,840 vaccine doses have been administered.
#
# our data set is gotten from [WHO](https://covid19.who.int/), the data is constantly being updated.

# %%
import pandas as pd 
import numpy as np
import os
import urllib
# %matplotlib inline

# %%
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data", "covid")

# %%
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path, "WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x232315bb988>)

# %%
df = pd.read_csv(csv_path)

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 202156    2022-04-30           ZW     Zimbabwe       AFRO         58
# 202157    2022-05-01           ZW     Zimbabwe       AFRO          0
# 202158    2022-05-02           ZW     Zimbabwe       AFRO          0
# 202159    2022-05-03           ZW     Zimbabwe       AFRO          0
# 202160    2022-05-04           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# 1                      0           0                  0
# 2                      0           0                  0
# 3                      0           0                  0
# 4                      0           0                  0
# ...                  ...         ...                ...
# 202156            247842           0               5469
# 202157            247842           0               5469
# 202158            247842           0               5469
# 202159            247842           0               5469
# 202160            247842           0               5469
#
# [202161 rows x 8 columns]

# %% [markdown]
# ### Let's get some infomation from our data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202161 entries, 0 to 202160
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      202161 non-null  object
#  1   Country_code       201308 non-null  object
#  2   Country            202161 non-null  object
#  3   WHO_region         202161 non-null  object
#  4   New_cases          202161 non-null  int64
#  5   Cumulative_cases   202161 non-null  int64
#  6   New_deaths         202161 non-null  int64
#  7   Cumulative_deaths  202161 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 12.3+ MB

# %%
df.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  2.021610e+05      2.021610e+05  202161.000000      202161.000000
# mean   2.535640e+03      6.309085e+05      30.881515       11830.825001
# std    1.664753e+04      3.354937e+06     163.375557       54976.114864
# min   -3.295200e+04      0.000000e+00   -2448.000000           0.000000
# 25%    0.000000e+00      2.010000e+02       0.000000           2.000000
# 50%    2.400000e+01      1.168000e+04       0.000000         151.000000
# 75%    5.090000e+02      1.654210e+05       6.000000        2778.000000
# max    1.252940e+06      8.067606e+07   11447.000000      986698.000000

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (202161, 8)

# %%
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
df.tail()
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 202156    2022-04-30           ZW  Zimbabwe       AFRO         58
# 202157    2022-05-01           ZW  Zimbabwe       AFRO          0
# 202158    2022-05-02           ZW  Zimbabwe       AFRO          0
# 202159    2022-05-03           ZW  Zimbabwe       AFRO          0
# 202160    2022-05-04           ZW  Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 202156            247842           0               5469
# 202157            247842           0               5469
# 202158            247842           0               5469
# 202159            247842           0               5469
# 202160            247842           0               5469

# %%
df_index = df.index
df_index
# Out:
# RangeIndex(start=0, stop=202161, step=1)

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([     0,      1,      2, ..., 202158, 202159, 202160], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2022-05-02', 'ZW', 'Zimbabwe', ..., 247842, 0, 5469],
#        ['2022-05-03', 'ZW', 'Zimbabwe', ..., 247842, 0, 5469],
#        ['2022-05-04', 'ZW', 'Zimbabwe', ..., 247842, 0, 5469]],
#       dtype=object)

# %%
df["Country"]
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 202156       Zimbabwe
# 202157       Zimbabwe
# 202158       Zimbabwe
# 202159       Zimbabwe
# 202160       Zimbabwe
# Name: Country, Length: 202161, dtype: object

# %%
df["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Falkland Islands (Malvinas)',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Holy See', 'Honduras',
#        'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Isle of Man',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo[1]', 'Kuwait',
#        'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia',
#        'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique',
#        'Mauritania', 'Mauritius', 'Mayotte', 'Mexico',
#        'Micronesia (Federated States of)', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North Macedonia',
#        'Northern Mariana Islands (Commonwealth of the)', 'Norway',
#        'occupied Palestinian territory, including east Jerusalem', 'Oman',
#        'Other', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea',
#        'Paraguay', 'Peru', 'Philippines', 'Pitcairn Islands', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Republic of Korea',
#        'Republic of Moldova', 'Réunion', 'Romania', 'Russian Federation',
#        'Rwanda', 'Saba', 'Saint Barthélemy', 'Saint Helena',
#        'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Eustatius', 'Sint Maarten', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Tajikistan', 'Thailand',
#        'The United Kingdom', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Republic of Tanzania',
#        'United States of America', 'United States Virgin Islands',
#        'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam',
#        'Wallis and Futuna', 'Yemen', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
# Let us strip out whitespace so we can use dot notation to index our dataFrame
df.columns = [col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.Country
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 202156       Zimbabwe
# 202157       Zimbabwe
# 202158       Zimbabwe
# 202159       Zimbabwe
# 202160       Zimbabwe
# Name: Country, Length: 202161, dtype: object

# %% [markdown]
# ###  Indexing individual rows and column

# %%
df.loc[1:4,'Country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
# Let's see countries where there are new cases
df.loc[1:10, ['Country','New_cases']]
# Out:
#         Country  New_cases
# 1   Afghanistan          0
# 2   Afghanistan          0
# 3   Afghanistan          0
# 4   Afghanistan          0
# 5   Afghanistan          0
# 6   Afghanistan          0
# 7   Afghanistan          0
# 8   Afghanistan          0
# 9   Afghanistan          0
# 10  Afghanistan          0

# %%
df.Country == 'United State of America'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 202156    False
# 202157    False
# 202158    False
# 202159    False
# 202160    False
# Name: Country, Length: 202161, dtype: bool

# %%
df[df.Country == 'United State of America']
# Out:
# Empty DataFrame
# Columns: [Date_reported, Country_code, Country, WHO_region, New_cases, Cumulative_cases, New_deaths, Cumulative_deaths]
# Index: []

# %%
# Let's see places where new death is greater than 1000
df[df.New_deaths > 1000]
# Out:
#        Date_reported Country_code                           Country  \
# 20721     2020-09-08           BO  Bolivia (Plurinational State of)
# 24023     2020-05-21           BR                            Brazil
# 24025     2020-05-23           BR                            Brazil
# 24026     2020-05-24           BR                            Brazil
# 24030     2020-05-28           BR                            Brazil
# ...              ...          ...                               ...
# 193582    2022-03-17           US          United States of America
# 193583    2022-03-18           US          United States of America
# 193584    2022-03-19           US          United States of America
# 193590    2022-03-25           US          United States of America
# 193597    2022-04-01           US          United States of America
#
#        WHO_region  New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 20721        AMRO        528            120769        1610               7008
# 24023        AMRO      17408            271628        1179              17971
# 24025        AMRO      18508            310087        1188              20047
# 24026        AMRO      20803            330890        1001              21048
# 24030        AMRO      16324            391222        1039              24512
# ...           ...        ...               ...         ...                ...
# 193582       AMRO      24417          78952606        1427             962817
# 193583       AMRO      37835          78990441        1491             964308
# 193584       AMRO      33075          79023516        1050             965358
# 193590       AMRO      45092          79182913        1235             969566
# 193597       AMRO      48207          79374583        1156             974019
#
# [964 rows x 8 columns]

# %%
# Specifically, which countries have new death greater than 1000
df.loc[df.New_deaths > 1000, ['New_deaths', 'Country']]
# Out:
#         New_deaths                           Country
# 20721         1610  Bolivia (Plurinational State of)
# 24023         1179                            Brazil
# 24025         1188                            Brazil
# 24026         1001                            Brazil
# 24030         1039                            Brazil
# ...            ...                               ...
# 193582        1427          United States of America
# 193583        1491          United States of America
# 193584        1050          United States of America
# 193590        1235          United States of America
# 193597        1156          United States of America
#
# [964 rows x 2 columns]

# %%
df.loc[(df.New_deaths > 1000) & (df.Country_code == 'US'), ['Date_reported', 'Country','New_cases','New_deaths','Cumulative_deaths']]
# Out:
#        Date_reported                   Country  New_cases  New_deaths  \
# 192869    2020-04-03  United States of America      28400        1121
# 192870    2020-04-04  United States of America      29912        1309
# 192871    2020-04-05  United States of America      31709        1369
# 192872    2020-04-06  United States of America      32491        1546
# 192873    2020-04-07  United States of America      27019        1869
# ...              ...                       ...        ...         ...
# 193582    2022-03-17  United States of America      24417        1427
# 193583    2022-03-18  United States of America      37835        1491
# 193584    2022-03-19  United States of America      33075        1050
# 193590    2022-03-25  United States of America      45092        1235
# 193597    2022-04-01  United States of America      48207        1156
#
#         Cumulative_deaths
# 192869               6070
# 192870               7379
# 192871               8748
# 192872              10294
# 192873              12163
# ...                   ...
# 193582             962817
# 193583             964308
# 193584             965358
# 193590             969566
# 193597             974019
#
# [385 rows x 5 columns]

# %% [markdown]
# ### The extrema

# %%
df.loc[df.Country_code == 'US', ['New_cases']].max()
# Out:
# New_cases    1252940
# dtype: int64

# %%
df.loc[df.Country_code == 'US', ['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code == 'US', ['New_cases']].sum()
# Out:
# New_cases    80676055
# dtype: int64

# %%
df.loc[df.Country_code == 'US', ['Cumulative_cases']].max()
# Out:
# Cumulative_cases    80676055
# dtype: int64

# %%
# Index number of maximum entry
df.New_deaths.idxmax()
# Out:
# 35782

# %%
df.loc[df.New_deaths.idxmax(), ['Date_reported', 'Country', 'New_cases', 'New_deaths']]
# Out:
# Date_reported    2022-03-22
# Country               Chile
# New_cases              8167
# New_deaths            11447
# Name: 35782, dtype: object

# %%
# Let's see where enew death is less tha zero
df[df.New_deaths < 0]
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 12182     2020-08-30           BS                   Bahamas       AMRO
# 14294     2021-10-10           BD                Bangladesh      SEARO
# 17481     2021-02-27           BZ                    Belize       AMRO
# 23825     2022-03-07           BW                  Botswana       AFRO
# 62018     2021-08-27           FR                    France       EURO
# 62027     2021-09-05           FR                    France       EURO
# 71768     2020-04-28           GP                Guadeloupe       AMRO
# 71949     2020-10-26           GP                Guadeloupe       AMRO
# 73469     2020-04-23           GT                 Guatemala       AMRO
# 73480     2020-05-04           GT                 Guatemala       AMRO
# 79704     2021-01-12           HN                  Honduras       AMRO
# 88033     2020-06-25           IT                     Italy       EURO
# 113614    2020-06-16           YT                   Mayotte       AFRO
# 147804    2020-08-25           RE                   Réunion       AFRO
# 166122    2021-10-04           XB            Sint Eustatius       AMRO
# 166129    2021-10-11           XB            Sint Eustatius       AMRO
# 173255    2020-04-08           LK                 Sri Lanka      SEARO
# 179454    2020-11-22           TH                  Thailand      SEARO
# 193581    2022-03-16           US  United States of America       AMRO
# 195084    2021-08-25           UY                   Uruguay       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 12182          37              2057         -10                 40
# 14294         481           1562359          -6              27688
# 17481           9             12280          -1                314
# 23825          18            304931          -8               2667
# 62018       18812           6511793          -6             112390
# 62027       13143           6627205         -32             112981
# 71768           0               149          -3                 10
# 71949           0              7474          -1                126
# 73469          22               316          -1                  8
# 73480          44               688          -1                 17
# 79704         719            127945          -2               3273
# 88033         178            239410         -31              34644
# 113614         28              2310          -1                 28
# 147804         35              1244          -4                  2
# 166122          0                28          -1                  0
# 166129          0                28          -1                  0
# 173255          6               186          -6                  0
# 179454         11              3913         -60                  0
# 193581      61318          78928189       -2448             961390
# 195084         87            384181          -1               6015

# %%
# let us create a column to hold the percentage of new cases
df['pct_cases'] = (df['New_cases'] / df['Cumulative_cases']) * 100
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 202156    2022-04-30           ZW     Zimbabwe       AFRO         58
# 202157    2022-05-01           ZW     Zimbabwe       AFRO          0
# 202158    2022-05-02           ZW     Zimbabwe       AFRO          0
# 202159    2022-05-03           ZW     Zimbabwe       AFRO          0
# 202160    2022-05-04           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  pct_cases
# 0                      0           0                  0        NaN
# 1                      0           0                  0        NaN
# 2                      0           0                  0        NaN
# 3                      0           0                  0        NaN
# 4                      0           0                  0        NaN
# ...                  ...         ...                ...        ...
# 202156            247842           0               5469   0.023402
# 202157            247842           0               5469   0.000000
# 202158            247842           0               5469   0.000000
# 202159            247842           0               5469   0.000000
# 202160            247842           0               5469   0.000000
#
# [202161 rows x 9 columns]
